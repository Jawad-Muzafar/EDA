# %% [markdown]
# # **Univariate eda**

# %% [markdown]
# # **Importing libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
plt.rcParams['figure.figsize']=(10,6)
plt.rcParams['font.size']=12
plt.rcParams['figure.dpi']=150

# %% [markdown]
# ## **Importing dataset**

# %%
df=pd.read_csv('C:/Data sets/Medicaldataset.csv')

# %% [markdown]
# ## **Have a look on five random rows of the dataset**

# %%
df.sample(5)
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 846    43       1         108                      100
# 589    79       1          89                      140
# 1229   75       1          63                      150
# 45     58       0          96                      111
# 549    32       0          67                      126
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 846                         71        259.0   4.21     0.005  negative
# 589                        100        157.0   4.74     0.191  positive
# 1229                        95        111.0   1.89     0.092  positive
# 45                          74         99.0   1.29     0.026  positive
# 549                         68        151.0   4.47     0.006  negative

# %% [markdown]
# ## **Shape of the dataset**

# %%
df.shape
# Out:
# (1319, 9)

# %% [markdown]
# ## **Applying statics function**

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1319 non-null   int64
#  1   Gender                    1319 non-null   int64
#  2   Heart rate                1319 non-null   int64
#  3   Systolic blood pressure   1319 non-null   int64
#  4   Diastolic blood pressure  1319 non-null   int64
#  5   Blood sugar               1319 non-null   float64
#  6   CK-MB                     1319 non-null   float64
#  7   Troponin                  1319 non-null   float64
#  8   Result                    1319 non-null   str
# dtypes: float64(3), int64(5), str(1)
# memory usage: 92.9 KB

# %%
df.describe()
# Out:
#                Age       Gender   Heart rate  Systolic blood pressure  \
# count  1319.000000  1319.000000  1319.000000              1319.000000
# mean     56.191812     0.659591    78.336619               127.170584
# std      13.647315     0.474027    51.630270                26.122720
# min      14.000000     0.000000    20.000000                42.000000
# 25%      47.000000     0.000000    64.000000               110.000000
# 50%      58.000000     1.000000    74.000000               124.000000
# 75%      65.000000     1.000000    85.000000               143.000000
# max     103.000000     1.000000  1111.000000               223.000000
#
#        Diastolic blood pressure  Blood sugar        CK-MB     Troponin
# count               1319.000000  1319.000000  1319.000000  1319.000000
# mean                  72.269143   146.634344    15.274306     0.360942
# std                   14.033924    74.923045    46.327083     1.154568
# min                   38.000000    35.000000     0.321000     0.001000
# 25%                   62.000000    98.000000     1.655000     0.006000
# 50%                   72.000000   116.000000     2.850000     0.014000
# 75%                   81.000000   169.500000     5.805000     0.085500
# max                  154.000000   541.000000   300.000000    10.300000

# %% [markdown]
# ## **Checking missing values**

# %%
df.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Heart rate                  0
# Systolic blood pressure     0
# Diastolic blood pressure    0
# Blood sugar                 0
# CK-MB                       0
# Troponin                    0
# Result                      0
# dtype: int64

# %% [markdown]
# ## **Checking duplicates rows**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## **Columns name**

# %%
df.columns.to_list()
# Out:
# ['Age',
#  'Gender',
#  'Heart rate',
#  'Systolic blood pressure',
#  'Diastolic blood pressure',
#  'Blood sugar',
#  'CK-MB',
#  'Troponin',
#  'Result']

# %% [markdown]
# ## **Checking skewness**

# %%
number=df.select_dtypes('number')
number.skew()
# Out:
# Age                         -0.239219
# Gender                      -0.674363
# Heart rate                  18.247720
# Systolic blood pressure      0.685246
# Diastolic blood pressure     0.489202
# Blood sugar                  1.933475
# CK-MB                        4.978095
# Troponin                     5.799107
# dtype: float64

# %%
df.head()
# Out:
#    Age  Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   64       1          66                      160                        83
# 1   21       1          94                       98                        46
# 2   55       1          64                      160                        77
# 3   64       1          70                      120                        55
# 4   55       1          64                      112                        65
#
#    Blood sugar  CK-MB  Troponin    Result
# 0        160.0   1.80     0.012  negative
# 1        296.0   6.75     1.060  positive
# 2        270.0   1.99     0.003  negative
# 3        270.0  13.87     0.122  positive
# 4        300.0   1.08     0.003  negative

# %% [markdown]
# ## **Age column**

# %%
df['Age']
# Out:
# 0       64
# 1       21
# 2       55
# 3       64
# 4       55
#         ..
# 1314    44
# 1315    66
# 1316    45
# 1317    54
# 1318    51
# Name: Age, Length: 1319, dtype: int64

# %%
print(df['Age'].max())
print(df['Age'].min())
print(df['Age'].mean())
# Out:
# 103
# 14
# 56.191811978771796

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
sns.histplot(df['Age'], kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
sns.boxplot(y=df['Age'])
plt.title('Age Box Plot')
plt.xlabel('Age')
plt.show()

# %%
sns.violinplot(y=df['Age'])
plt.title('Age Violin Plot')
plt.xlabel('Age')
plt.show()

# %%
df.head()
# Out:
#    Age  Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   64       1          66                      160                        83
# 1   21       1          94                       98                        46
# 2   55       1          64                      160                        77
# 3   64       1          70                      120                        55
# 4   55       1          64                      112                        65
#
#    Blood sugar  CK-MB  Troponin    Result
# 0        160.0   1.80     0.012  negative
# 1        296.0   6.75     1.060  positive
# 2        270.0   1.99     0.003  negative
# 3        270.0  13.87     0.122  positive
# 4        300.0   1.08     0.003  negative

# %% [markdown]
# ## **Gender column**

# %%
df['Gender']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1314    1
# 1315    1
# 1316    1
# 1317    1
# 1318    1
# Name: Gender, Length: 1319, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# 1    870
# 0    449
# Name: count, dtype: int64

# %%
df['Gender'].isnull().sum()
# Out:
# 0

# %%
sns.countplot(x=df['Gender'],palette='Set2')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
df.head()
# Out:
#    Age  Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   64       1          66                      160                        83
# 1   21       1          94                       98                        46
# 2   55       1          64                      160                        77
# 3   64       1          70                      120                        55
# 4   55       1          64                      112                        65
#
#    Blood sugar  CK-MB  Troponin    Result
# 0        160.0   1.80     0.012  negative
# 1        296.0   6.75     1.060  positive
# 2        270.0   1.99     0.003  negative
# 3        270.0  13.87     0.122  positive
# 4        300.0   1.08     0.003  negative

# %% [markdown]
# ## **Heartrate column**

# %%
df['Heart rate']
# Out:
# 0       66
# 1       94
# 2       64
# 3       70
# 4       64
#         ..
# 1314    94
# 1315    84
# 1316    85
# 1317    58
# 1318    94
# Name: Heart rate, Length: 1319, dtype: int64

# %%
df['Heart rate'].isnull().sum()
# Out:
# 0

# %%
sns.histplot(df['Heart rate'], kde=True)
# Out:
# <Axes: xlabel='Heart rate', ylabel='Count'>

# %%
sns.boxplot(df['Heart rate'])
plt.title('Heart Rate Box Plot')
plt.xlabel('Heart Rate')
plt.show()

# %%
sns.violinplot(y=df['Heart rate'])
# Out:
# <Axes: ylabel='Heart rate'>

# %%
print(df['Heart rate'].min())
print(df['Heart rate'].max())
print(df['Heart rate'].mean())
# Out:
# 20
# 1111
# 78.3366186504928

# %% [markdown]
# ## Removing the outlier

# %%
df[df['Heart rate']==1111].value_counts()
# Out:
# Age  Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  Blood sugar  CK-MB  Troponin  Result
# 45   1       1111        141                      95                        109.0        1.33   1.010     positive    1
# 70   0       1111        141                      95                        138.0        3.87   0.028     positive    1
# 32   0       1111        141                      95                        82.0         2.66   0.008     negative    1
# Name: count, dtype: int64
