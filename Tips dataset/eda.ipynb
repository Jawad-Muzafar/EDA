# %% [markdown]
# # **EDA on tips data set**

# %% [markdown]
# ## **Importing libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split

# %%
plt.rcParams['figure.figsize']=(10,6)
plt.rcParams['figure.dpi']=150
plt.rcParams['font.size']=12

# %% [markdown]
# ## **Loading dataset**

# %%
df=sns.load_dataset('tips')

# %% [markdown]
# ## **Have a look on 5 random rows of data set**

# %%
df.sample(5)
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 156       48.17  5.0    Male     No   Sun  Dinner     6
# 89        21.16  3.0    Male     No  Thur   Lunch     2
# 92         5.75  1.0  Female    Yes   Fri  Dinner     2
# 234       15.53  3.0    Male    Yes   Sat  Dinner     2
# 74        14.73  2.2  Female     No   Sat  Dinner     2

# %% [markdown]
# ## **Shape of the dataset**

# %%
df.shape
# Out:
# (244, 7)

# %% [markdown]
# ## **Applying statics function**

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# ## **Checking missing values of the data**

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# ## **Checking duplicate rows**

# %%
df.duplicated().sum()
# Out:
# 1

# %% [markdown]
# ## Deleting duplicate row

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## **total bill column**

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 243, dtype: float64

# %%
df['total_bill'].isnull().sum()
# Out:
# 0

# %%
sns.histplot(df['total_bill'], kde=True)
plt.title('Distribution of Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Count')
plt.show()

# %%
sns.boxplot(df['total_bill'])
plt.title('Box plot of the total bill')
plt.xlabel('Total bill')
plt.ylabel('Count')
plt.show()

# %%
sns.violinplot(df['total_bill'])
plt.title('Violin plot of the total bill')
plt.ylabel('total bill')
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## **Tip column**

# %%
df['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 243, dtype: float64

# %%
df['tip'].isnull().sum()
# Out:
# 0

# %%
sns.histplot(df['tip'], kde=True)
plt.title('Distribution of Tip')
plt.xlabel('Tip')
plt.ylabel('Count')
plt.show()

# %%
sns.boxplot(df['tip'])
plt.title('Box plot of the tip')
plt.xlabel('Tip')
plt.ylabel('Count')
plt.show()

# %%
sns.violinplot(df['tip'])
plt.title('Violin plot of the tip')
plt.ylabel('tip')
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## **Sex column**

# %%
df['sex']
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 243, dtype: category
# Categories (2, str): ['Male', 'Female']

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     86
# Name: count, dtype: int64

# %%
df['sex'].isnull().sum()
# Out:
# 0

# %%
sns.countplot(x='sex', data=df,palette='Set2')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Count of Each Sex')
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## **Smoker column**

# %%
df['smoker']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 243, dtype: category
# Categories (2, str): ['Yes', 'No']

# %%
df['smoker'].isnull().sum()
# Out:
# 0

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     92
# Name: count, dtype: int64

# %%
sns.countplot(x='smoker', data=df,palette='Set2')
plt.title('Count of Each Smoker Status')
plt.xlabel('Smoker Status')
plt.ylabel('Count')
plt.show()

# %%
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## **Day column**

# %%
df['day']
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 243, dtype: category
# Categories (4, str): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
df['day'].isnull().sum()
# Out:
# 0

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    61
# Fri     19
# Name: count, dtype: int64

# %%
sns.countplot(x='day', data=df,palette='Set1')
plt.title('Count of Each Day')
plt.xlabel('Day')
plt.ylabel('Count')
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## **Time column**

# %%
df['time']
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
#         ...
# 239    Dinner
# 240    Dinner
# 241    Dinner
# 242    Dinner
# 243    Dinner
# Name: time, Length: 243, dtype: category
# Categories (2, str): ['Lunch', 'Dinner']

# %%
df['time'].isnull().sum()
# Out:
# 0

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      67
# Name: count, dtype: int64

# %%
sns.countplot(x='time', data=df,palette='Set1')
plt.title('Count of Each Time')
plt.xlabel('Time')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## **Size column**

# %%
df['size']
# Out:
# 0      2
# 1      3
# 2      3
# 3      2
# 4      4
#       ..
# 239    3
# 240    2
# 241    2
# 242    2
# 243    2
# Name: size, Length: 243, dtype: int64

# %%
df['size'].isnull().sum()
# Out:
# 0

# %%
df['size'].value_counts()
# Out:
# size
# 2    155
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
sns.countplot(x='size', data=df,palette='Set1')
plt.title('Count of Each Size')
plt.xlabel('Size')
plt.ylabel('Count')
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # **Bivariate EDA**

# %% [markdown]
# ## **Total bill and tips column**

# %%
sns.scatterplot(x='total_bill', y='tip', data=df,palette='Set')
plt.title('Scatter plot of Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## **Sex and tip column**

# %%
df.groupby('sex')['tip'].mean()
# Out:
# sex
# Male      3.089618
# Female    2.843140
# Name: tip, dtype: float64

# %%
sns.barplot(y='tip',hue='sex',data=df,palette='Set1')
# Out:
# <Axes: ylabel='tip'>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## **Smoker and tip column**

# %%
df.groupby('smoker')['tip'].mean()
# Out:
# smoker
# Yes    3.019674
# No     2.991854
# Name: tip, dtype: float64

# %%
sns.barplot(y='tip',hue='sex',palette='Set1',data=df)
plt.title('Tip with the smoker')
plt.xlabel('Count')
plt.ylabel('Tip')
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## **Tip and day column**

# %%
df.groupby('day')['tip'].mean()
# Out:
# day
# Thur    2.784098
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64

# %%
sns.barplot(y='tip',hue='day',palette='Set1',data=df)
plt.title('Tip with the day')
plt.xlabel('Count')
plt.ylabel('Tip')
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## **Time and tip column**

# %%
df.groupby('time')['tip'].mean()
# Out:
# time
# Lunch     2.738955
# Dinner    3.102670
# Name: tip, dtype: float64

# %%
sns.barplot(y='tip',hue='time',palette='Set1',data=df)
plt.title('Tip with the time')
plt.xlabel('Count')
plt.ylabel('Tip')
plt.show()

# %% [markdown]
# ## **Size and tip column**

# %%
df.groupby('size')['tip'].mean()
# Out:
# size
# 1    1.437500
# 2    2.586065
# 3    3.393158
# 4    4.135405
# 5    4.028000
# 6    5.225000
# Name: tip, dtype: float64

# %%
sns.barplot(y='tip',hue='size',palette='Set1',data=df)
plt.title('Count of the sex with the tip')
plt.ylabel('Tip')
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## **Smoker and sex column**

# %%
df.groupby('smoker')['sex'].value_counts()
# Out:
# smoker  sex
# Yes     Male      60
#         Female    32
# No      Male      97
#         Female    54
# Name: count, dtype: int64

# %%
sns.countplot(x='smoker',hue='sex',data=df,palette='Set1')
plt.title('Count of the sex with the smoker')
plt.xlabel('Smoker')
plt.ylabel('Count')
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## **Sex and day column**

# %%
sd=df.groupby('sex')['day'].value_counts().reset_index(name='count').rename(columns={'sex':'Sex','day':'Day','count':'Count'})
sd
# Out:
#       Sex   Day  Count
# 0    Male   Sat     59
# 1    Male   Sun     58
# 2    Male  Thur     30
# 3    Male   Fri     10
# 4  Female  Thur     31
# 5  Female   Sat     28
# 6  Female   Sun     18
# 7  Female   Fri      9

# %%
sns.catplot(x='Day',y='Count',hue='Sex',data=sd,kind='bar',palette='Set1')
plt.title('Count of the sex with the day')
plt.xlabel('Day')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## **Time and sex column**

# %%
st=df.groupby('sex')['time'].value_counts().reset_index(name='count').rename(columns={'sex':'Sex','time':'Time','count':'Count'})
st
# Out:
#       Sex    Time  Count
# 0    Male  Dinner    124
# 1    Male   Lunch     33
# 2  Female  Dinner     52
# 3  Female   Lunch     34

# %%
sns.barplot(x='Time',y='Count',hue='Sex',data=st,palette='Set1',order=['Lunch','Dinner'])
plt.title('Count of the sex with the time')
plt.xlabel('Time')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## **Time and smoker column**

# %%
df.groupby('time')['smoker'].value_counts()
# Out:
# time    smoker
# Lunch   No         45
#         Yes        22
# Dinner  No        106
#         Yes        70
# Name: count, dtype: int64

# %%
sns.countplot(x='time',hue='smoker',data=df,palette='Set1')
plt.title('Count of the smoker with the time')
plt.xlabel('Time')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## **Smoker and day**

# %%
df.groupby('smoker')['day'].value_counts()
# Out:
# smoker  day
# Yes     Sat     42
#         Sun     19
#         Thur    16
#         Fri     15
# No      Sun     57
#         Sat     45
#         Thur    45
#         Fri      4
# Name: count, dtype: int64

# %%
sns.countplot(x='day',hue='smoker',data=df,palette='Set1',order=['Thur','Fri','Sat','Sun'])
plt.title('Count of the smoker with the day')
plt.xlabel('Day')
plt.ylabel('Count')
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## **Size and sex column**

# %%
df.groupby('size')['sex'].value_counts()
# Out:
# size  sex
# 1     Female     3
#       Male       1
# 2     Male      98
#       Female    57
# 3     Male      24
#       Female    14
# 4     Male      28
#       Female     9
# 5     Male       4
#       Female     1
# 6     Female     2
#       Male       2
# Name: count, dtype: int64

# %%
sns.countplot(x='size',hue='sex',data=df,palette='Set1')
plt.title('Count of the sex with the size')
plt.xlabel('Size')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## **Smoker and size column**

# %%
df.groupby('size')['smoker'].value_counts()
# Out:
# size  smoker
# 1     No         2
#       Yes        2
# 2     No        90
#       Yes       65
# 3     No        26
#       Yes       12
# 4     No        26
#       Yes       11
# 5     No         3
#       Yes        2
# 6     No         4
#       Yes        0
# Name: count, dtype: int64

# %%
sns.countplot(x='day',hue='smoker',data=df,palette='Set1')
plt.title('Count of the smoker with the day')
# Out:
# Text(0.5, 1.0, 'Count of the smoker with the day')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # **Multivariate EDA**

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## **Sex + total bill with tip column**

# %%
df.groupby(['sex','total_bill'])['tip'].size()
# Out:
# sex     total_bill
# Male    7.25          1
#         7.51          1
#         7.56          1
#         7.74          1
#         8.52          1
#                      ..
# Female  34.83         1
#         35.26         1
#         35.83         1
#         43.11         1
#         44.30         1
# Name: tip, Length: 235, dtype: int64

# %%
sns.scatterplot(x='total_bill', y='tip', data=df, hue='sex', palette='Set1')
plt.title('Scatter plot of Total Bill vs Tip by Sex')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
sns.scatterplot(x='total_bill', y='tip', data=df, hue='smoker', palette='Set1')
plt.title('Scatter plot of Total Bill vs Tip by Sex')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## **Total bill and sex with smoker column**

# %%
sns.catplot(data=df,y='total_bill',hue='sex',col='smoker',kind='box')
plt.show()

# %%
sns.catplot(data=df,y='total_bill',hue='sex',col='smoker',kind='bar')
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.groupby(['sex','smoker'])['total_bill'].max()
# Out:
# sex     smoker
# Male    Yes       50.81
#         No        48.33
# Female  Yes       44.30
#         No        35.83
# Name: total_bill, dtype: float64

# %% [markdown]
# ## **Total bill and day with smoker column**

# %%
sns.catplot(x='day',y='total_bill',hue='sex',col='smoker',data=df,kind='bar')
plt.show()
